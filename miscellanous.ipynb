# %% [markdown]
# <a href="https://colab.research.google.com/github/saigalsaigal2004-eng/python_basics/blob/main/miscellanous.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
class Employee:
  def __init__(self, name, age, salary):
    self.name = "rahul"
    self.password = "1234"
    self.salary = 50000
  def show_details(self):
    print(self.name)
    print(self.password)
    print(self.salary)
  e = Employee()
  e.show_details
  print(e.password)

  emp = Employee()
  print(emp.name)
  print(emp.salary)
  prnt(emp.password)

  emp.show_details()
  print(emp.name)
  print(emp.salary)
  prnt(emp.password)

  class Manager:
    def show_manager(self):
      print("name:",self.name)
      print("password:",self.password)
Manager.show_manager()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_431/341349648.py in <cell line: 0>()
# ----> 1 class Employee:
#       2   def __init__(self, name, age, salary):
#       3     self.name = "rahul"
#       4     self.password = "1234"
#       5     self.salary = 50000
#
# /tmp/ipykernel_431/341349648.py in Employee()
#       8     print(self.password)
#       9     print(self.salary)
# ---> 10   e = Employee()
#      11   e.show_details
#      12   print(e.password)
#
# NameError: name 'Employee' is not defined
